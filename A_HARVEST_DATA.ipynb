# %% [markdown]
# # Load Packages

# %%
import requests
from bs4 import BeautifulSoup
from datetime import datetime
import pandas as pd
import os
from pathlib import Path

# %% [markdown]
# # Harvest Data Functions

# %%
# --- CONFIGURATION ---

USER_AGENT = "Mozilla/5.0 (compatible; NHANES-scraper/1.0)"
DEFAULT_TIMEOUT = 30

SESSION = requests.Session()
SESSION.headers.update({"User-Agent": USER_AGENT})

DEFAULT_LOGFILE = "log.txt"
CDC_BASE_URL = "https://wwwn.cdc.gov"
NHANES_BASE_URL = "https://wwwn.cdc.gov/nchs/nhanes/"
CYCLE_2017_2020_ROOT_URL = "https://wwwn.cdc.gov/nchs/nhanes/continuousnhanes/default.aspx?Cycle=2017-2020" # Only using 2017 - 2020 for now

# --- END CONFIGURATION ---

# --- HELPER FUNCTIONS ---
def log(message, logfile="log.txt"):
    timestamp = datetime.now().strftime("%Y-%m-%d %H:%M:%S")
    with open(logfile, "a", encoding="utf-8") as f:
        f.write(f"[{timestamp}] {message}\n")

def clean_text(text: str):
    text = text.strip()
    text = text.replace(" ", "_")
    text = text.lower()
    return text

def clean_href(base_url, a):
    try:
        if not a:
            raise Exception("Anchor doesn't exist!")
        if not a.has_attr("href"):
            raise Exception("Anchor doesn't have href!")
        
        href = a["href"].strip()
        if href.startswith("../"): 
            href = base_url + href[3:] 
        else: 
            href = base_url + href 
            return href
        
        return href
    except Exception as e:
        log(f"Expt in clean_href: {str(e)}")
        return None

def get_soup(url) -> BeautifulSoup:
    r = SESSION.get(url, timeout=30)
    r.raise_for_status()
    soup = BeautifulSoup(r.text, 'html.parser')
    return soup

# --- END HELPER FUNCTIONS ---

# --- SCRAPING FUNCTIONS ---

# DDC = Data, Documentation, Codebook
def get_ddc_links(nhanes_root_soup: BeautifulSoup) -> dict:
    table = nhanes_root_soup.find(
        "div",
        attrs = {'class': 'card-body bg-white no-padding'}
    )
    a_elements = table.find_all('a')

    links = {}
    for a_element in a_elements:
        name = clean_text(a_element.contents[-1])
        link = clean_href(NHANES_BASE_URL, a_element)
        links[name] = link
    return links


def get_category_subset_df(url) -> pd.DataFrame:
    soup = get_soup(url)
    table = soup.find('table', {'id': 'GridView1'}) # Tables are easily identified by id
    # Keep it really simply, get headers, get rows + links, create df

    # Get natural headers
    headers = []
    for th in table.find('thead').find_all('th'):
        headers.append(clean_text(th.contents[0]))

    # Create array of dictionaries from rows:
    rows = []
    for tr in table.find("tbody").find_all("tr"):
        tds = tr.find_all("td")

        # basic text
        text_data = [
            td.get_text(strip=True) for td in tds
        ]

        # pick out anchors
        doc_a  = tds[2].find("a")
        data_a = tds[3].find("a")

        # build absolute URLs manually
        doc_url  = clean_href(CDC_BASE_URL, doc_a)
        data_url = clean_href(CDC_BASE_URL, data_a)

        row = dict(zip(headers, text_data))
        row["doc_url"] = doc_url
        row["data_url"] = data_url

        rows.append(row)
    
    # Create df
    df = pd.DataFrame(rows)
    return df

def download_file(url, file_dir, write_log = True):
    r = SESSION.get(url, stream=True)
    r.raise_for_status()

    file_name = os.path.basename(url)
    if not os.path.exists(file_dir):
        os.makedirs(file_dir)

    save_path = os.path.join(file_dir, file_name)
    with open(save_path, 'wb') as f:
        for chunk in r.iter_content(chunk_size=16*1024):
            f.write(chunk)
    
    if write_log:
        log(f"{file_name} downloaded successfully to {save_path}")

def download_category_subset(cycle, category_subset):
    for row in cycle[category_subset].to_dict("records"):
        url = row['data_url']
        if not url:
            log(f"{category_subset}: No data url found! Cannot download")
            continue
        download_file(url, "./RAW/DATA/" + category_subset)
        print(f"Successfully downloaded {url}")

def get_codebook_df(doc_url):
    results = []
    soup = get_soup(doc_url)
    codebook = soup.find('div', {'id': 'Codebook'})
    if not codebook:
        print(f"Can't find codebook for {doc_url}!")
        log(f"Can't find codebook for {doc_url}!")
        return pd.DataFrame()
    for div in codebook.find_all('div', {'class': 'pagebreak'}):
        code = {}
        dl = div.find('dl')
        for dt in dl.find_all('dt'):
            dd = dt.find_next_sibling('dd')

            code_feature_name = clean_text(dt.get_text()).rstrip(":")
            code_feature_value = dd.get_text()
            code[code_feature_name] = code_feature_value
            
        table = div.find('table')
        code['table'] = str(table)
            
        results.append(code)
    return pd.DataFrame(results)

def get_category_subset_codebook(cycle, category_subset):
    for row in cycle[category_subset].to_dict("records"):
        doc_url = row['doc_url']
        if not doc_url:
            log(f"{category_subset}: No doc url found! Cannot get codebook")
            continue
        CODEBOOKS_PATH = f"./RAW/CODEBOOKS/{category_subset}"

        if not os.path.exists(CODEBOOKS_PATH):
            os.makedirs(CODEBOOKS_PATH)
        url = row['data_url']
        if not url:
            log(f"{category_subset}: No data url found! Cannot download")
            continue
        file_name = os.path.basename(url).split('.')[0]
        doc_df = get_codebook_df(doc_url)
        doc_df['data_file'] = file_name
        doc_df.to_csv(CODEBOOKS_PATH + f"/{file_name}_codebook.csv", index = False)
# --- END SCRAPING FUNCTIONS ---

# %% [markdown]
# # Perform Harvesting

# %%
# Get links from the main root cycle page
links = get_ddc_links(get_soup(CYCLE_2017_2020_ROOT_URL))

# Create dataframes with subcategory information
cycle_2017_2020_dfs = {}
for name, link in links.items():
    print(name, link)
    cycle_2017_2020_dfs[name] = get_category_subset_df(link)

# For subcategory, download the data
for category_subset in cycle_2017_2020_dfs.keys():
    download_category_subset(cycle_2017_2020_dfs, category_subset)

# For subcategory, get the codebooks
for category_subset in cycle_2017_2020_dfs.keys():
    get_category_subset_codebook(cycle_2017_2020_dfs, category_subset)
# Out:
# demographics_data https://wwwn.cdc.gov/nchs/nhanes/search/datapage.aspx?Component=Demographics&Cycle=2017-2020
# dietary_data https://wwwn.cdc.gov/nchs/nhanes/search/datapage.aspx?Component=Dietary&Cycle=2017-2020
# examination_data https://wwwn.cdc.gov/nchs/nhanes/search/datapage.aspx?Component=Examination&Cycle=2017-2020
# laboratory_data https://wwwn.cdc.gov/nchs/nhanes/search/datapage.aspx?Component=Laboratory&Cycle=2017-2020
# questionnaire_data https://wwwn.cdc.gov/nchs/nhanes/search/datapage.aspx?Component=Questionnaire&Cycle=2017-2020
# limited_access_data https://wwwn.cdc.gov/nchs/nhanes/search/datapage.aspx?Component=LimitedAccess&Cycle=2017-2020
# Successfully downloaded https://wwwn.cdc.gov/Nchs/Data/Nhanes/Public/2017/DataFiles/P_DEMO.xpt
# Successfully downloaded https://wwwn.cdc.gov/Nchs/Data/Nhanes/Public/2017/DataFiles/P_DR1IFF.xpt
# Successfully downloaded https://wwwn.cdc.gov/Nchs/Data/Nhanes/Public/2017/DataFiles/P_DR2IFF.xpt
# Successfully downloaded https://wwwn.cdc.gov/Nchs/Data/Nhanes/Public/2017/DataFiles/P_DR1TOT.xpt
# Successfully downloaded https://wwwn.cdc.gov/Nchs/Data/Nhanes/Public/2017/DataFiles/P_DR2TOT.xpt
# Successfully downloaded https://wwwn.cdc.gov/Nchs/Data/Nhanes/Public/2017/DataFiles/P_DRXFCD.xpt
# Successfully downloaded https://wwwn.cdc.gov/Nchs/Data/Nhanes/Public/1999/DataFiles/DSBI.xpt
# Successfully downloaded https://wwwn.cdc.gov/Nchs/Data/Nhanes/Public/1999/DataFiles/DSII.xpt
# Successfully downloaded https://wwwn.cdc.gov/Nchs/Data/Nhanes/Public/1999/DataFiles/DSPI.xpt
# Successfully downloaded https://wwwn.cdc.gov/Nchs/Data/Nhanes/Public/2017/DataFiles/P_DS1IDS.xpt
# Successfully downloaded https://wwwn.cdc.gov/Nchs/Data/Nhanes/Public/2017/DataFiles/P_DS2IDS.xpt
# Successfully downloaded https://wwwn.cdc.gov/Nchs/Data/Nhanes/Public/2017/DataFiles/P_DS1TOT.xpt
# Successfully downloaded https://wwwn.cdc.gov/Nchs/Data/Nhanes/Public/2017/DataFiles/P_DS2TOT.xpt
# Successfully downloaded https://wwwn.cdc.gov/Nchs/Data/Nhanes/Public/2017/DataFiles/P_DSQIDS.xpt
# Successfully downloaded https://wwwn.cdc.gov/Nchs/Data/Nhanes/Public/2017/DataFiles/P_DSQTOT.xpt
# Successfully downloaded https://wwwn.cdc.gov/Nchs/Data/Nhanes/Public/2017/DataFiles/P_AUX.xpt
# Successfully downloaded https://wwwn.cdc.gov/Nchs/Data/Nhanes/Public/2017/DataFiles/P_AUXAR.xpt
# Successfully downloaded https://wwwn.cdc.gov/Nchs/Data/Nhanes/Public/2017/DataFiles/P_AUXTYM.xpt
# Successfully downloaded https://wwwn.cdc.gov/Nchs/Data/Nhanes/Public/2017/DataFiles/P_AUXWBR.xpt
# Successfully downloaded https://wwwn.cdc.gov/Nchs/Data/Nhanes/Public/2017/DataFiles/P_BPXO.xpt
# Successfully downloaded https://wwwn.cdc.gov/Nchs/Data/Nhanes/Public/2017/DataFiles/P_BMX.xpt
# Successfully downloaded https://wwwn.cdc.gov/Nchs/Data/Nhanes/Public/2017/DataFiles/P_DXXFEM.xpt
# Successfully downloaded https://wwwn.cdc.gov/Nchs/Data/Nhanes/Public/2017/DataFiles/P_DXXSPN.xpt
# Successfully downloaded https://wwwn.cdc.gov/Nchs/Data/Nhanes/Public/2017/DataFiles/P_LUX.xpt
# Successfully downloaded https://wwwn.cdc.gov/Nchs/Data/Nhanes/Public/2017/DataFiles/P_OHXDEN.xpt
# Successfully downloaded https://wwwn.cdc.gov/Nchs/Data/Nhanes/Public/2017/DataFiles/P_OHXREF.xpt
# Successfully downloaded https://wwwn.cdc.gov/Nchs/Data/Nhanes/Public/2017/DataFiles/P_ALB_CR.xpt
# Successfully downloaded https://wwwn.cdc.gov/Nchs/Data/Nhanes/Public/2017/DataFiles/P_SSAGP.xpt
# Successfully downloaded https://wwwn.cdc.gov/Nchs/Data/Nhanes/Public/2017/DataFiles/P_UTAS.xpt
# Successfully downloaded https://wwwn.cdc.gov/Nchs/Data/Nhanes/Public/2017/DataFiles/P_UAS.xpt
# Successfully downloaded https://wwwn.cdc.gov/Nchs/Data/Nhanes/Public/2017/DataFiles/P_HDL.xpt
# Successfully downloaded https://wwwn.cdc.gov/Nchs/Data/Nhanes/Public/2017/DataFiles/P_TRIGLY.xpt
# Successfully downloaded https://wwwn.cdc.gov/Nchs/Data/Nhanes/Public/2017/DataFiles/P_TCHOL.xpt
# Successfully downloaded https://wwwn.cdc.gov/Nchs/Data/Nhanes/Public/2017/DataFiles/P_UCM.xpt
# Successfully downloaded https://wwwn.cdc.gov/Nchs/Data/Nhanes/Public/2017/DataFiles/P_CRCO.xpt
# Successfully downloaded https://wwwn.cdc.gov/Nchs/Data/Nhanes/Public/2017/DataFiles/P_CBC.xpt
# Successfully downloaded https://wwwn.cdc.gov/Nchs/Data/Nhanes/Public/2017/DataFiles/P_COT.xpt
# Successfully downloaded https://wwwn.cdc.gov/Nchs/Data/Nhanes/Public/2017/DataFiles/P_CMV.xpt
# Successfully downloaded https://wwwn.cdc.gov/Nchs/Data/Nhanes/Public/2017/DataFiles/P_ETHOX.xpt
# Successfully downloaded https://wwwn.cdc.gov/Nchs/Data/Nhanes/Public/2017/DataFiles/P_FASTQX.xpt
# Successfully downloaded https://wwwn.cdc.gov/Nchs/Data/Nhanes/Public/2017/DataFiles/P_FERTIN.xpt
# Successfully downloaded https://wwwn.cdc.gov/Nchs/Data/Nhanes/Public/2017/DataFiles/P_FR.xpt
# Successfully downloaded https://wwwn.cdc.gov/Nchs/Data/Nhanes/Public/2017/DataFiles/P_SSFR.xpt
# Successfully downloaded https://wwwn.cdc.gov/Nchs/Data/Nhanes/Public/2017/DataFiles/P_FOLATE.xpt
# Successfully downloaded https://wwwn.cdc.gov/Nchs/Data/Nhanes/Public/2017/DataFiles/P_FOLFMS.xpt
# Successfully downloaded https://wwwn.cdc.gov/Nchs/Data/Nhanes/Public/2017/DataFiles/P_GHB.xpt
# Successfully downloaded https://wwwn.cdc.gov/Nchs/Data/Nhanes/Public/2017/DataFiles/P_HEPA.xpt
# Successfully downloaded https://wwwn.cdc.gov/Nchs/Data/Nhanes/Public/2017/DataFiles/P_HEPB_S.xpt
# Successfully downloaded https://wwwn.cdc.gov/Nchs/Data/Nhanes/Public/2017/DataFiles/P_HEPBD.xpt
# Successfully downloaded https://wwwn.cdc.gov/Nchs/Data/Nhanes/Public/2017/DataFiles/P_HEPC.xpt
# Successfully downloaded https://wwwn.cdc.gov/Nchs/Data/Nhanes/Public/2017/DataFiles/P_HEPE.xpt
# Successfully downloaded https://wwwn.cdc.gov/Nchs/Data/Nhanes/Public/2017/DataFiles/P_HSCRP.xpt
# Successfully downloaded https://wwwn.cdc.gov/Nchs/Data/Nhanes/Public/2017/DataFiles/P_IHGEM.xpt
# Successfully downloaded https://wwwn.cdc.gov/Nchs/Data/Nhanes/Public/2017/DataFiles/P_INS.xpt
# Successfully downloaded https://wwwn.cdc.gov/Nchs/Data/Nhanes/Public/2017/DataFiles/P_UIO.xpt
# Successfully downloaded https://wwwn.cdc.gov/Nchs/Data/Nhanes/Public/2017/DataFiles/P_FETIB.xpt
# Successfully downloaded https://wwwn.cdc.gov/Nchs/Data/Nhanes/Public/2017/DataFiles/P_PBCD.xpt
# Successfully downloaded https://wwwn.cdc.gov/Nchs/Data/Nhanes/Public/2017/DataFiles/P_UHG.xpt
# Successfully downloaded https://wwwn.cdc.gov/Nchs/Data/Nhanes/Public/2017/DataFiles/P_UM.xpt
# Successfully downloaded https://wwwn.cdc.gov/Nchs/Data/Nhanes/Public/2017/DataFiles/P_UNI.xpt
# Successfully downloaded https://wwwn.cdc.gov/Nchs/Data/Nhanes/Public/2017/DataFiles/P_OPD.xpt
# Successfully downloaded https://wwwn.cdc.gov/Nchs/Data/Nhanes/Public/2017/DataFiles/P_PERNT.xpt
# Successfully downloaded https://wwwn.cdc.gov/Nchs/Data/Nhanes/Public/2017/DataFiles/P_PFAS.xpt
# Successfully downloaded https://wwwn.cdc.gov/Nchs/Data/Nhanes/Public/2017/DataFiles/P_GLU.xpt
# Successfully downloaded https://wwwn.cdc.gov/Nchs/Data/Nhanes/Public/2017/DataFiles/P_TST.xpt
# Successfully downloaded https://wwwn.cdc.gov/Nchs/Data/Nhanes/Public/2017/DataFiles/P_BIOPRO.xpt
# Successfully downloaded https://wwwn.cdc.gov/Nchs/Data/Nhanes/Public/2017/DataFiles/P_TFR.xpt
# Successfully downloaded https://wwwn.cdc.gov/Nchs/Data/Nhanes/Public/2017/DataFiles/P_UCFLOW.xpt
# Successfully downloaded https://wwwn.cdc.gov/Nchs/Data/Nhanes/Public/2017/DataFiles/P_UCPREG.xpt
# Successfully downloaded https://wwwn.cdc.gov/Nchs/Data/Nhanes/Public/2017/DataFiles/P_UVOC.xpt
# Successfully downloaded https://wwwn.cdc.gov/Nchs/Data/Nhanes/Public/2017/DataFiles/P_UVOC2.xpt
# Successfully downloaded https://wwwn.cdc.gov/Nchs/Data/Nhanes/Public/2017/DataFiles/P_VOCWB.xpt
# Successfully downloaded https://wwwn.cdc.gov/Nchs/Data/Nhanes/Public/2017/DataFiles/P_ACQ.xpt
# Successfully downloaded https://wwwn.cdc.gov/Nchs/Data/Nhanes/Public/2017/DataFiles/P_ALQ.xpt
# Successfully downloaded https://wwwn.cdc.gov/Nchs/Data/Nhanes/Public/2017/DataFiles/P_AUQ.xpt
# Successfully downloaded https://wwwn.cdc.gov/Nchs/Data/Nhanes/Public/2017/DataFiles/P_BPQ.xpt
# Successfully downloaded https://wwwn.cdc.gov/Nchs/Data/Nhanes/Public/2017/DataFiles/P_CDQ.xpt
# Successfully downloaded https://wwwn.cdc.gov/Nchs/Data/Nhanes/Public/2017/DataFiles/P_CBQPFA.xpt
# Successfully downloaded https://wwwn.cdc.gov/Nchs/Data/Nhanes/Public/2017/DataFiles/P_CBQPFC.xpt
# Successfully downloaded https://wwwn.cdc.gov/Nchs/Data/Nhanes/Public/2017/DataFiles/P_HSQ.xpt
# Successfully downloaded https://wwwn.cdc.gov/Nchs/Data/Nhanes/Public/2017/DataFiles/P_DEQ.xpt
# Successfully downloaded https://wwwn.cdc.gov/Nchs/Data/Nhanes/Public/2017/DataFiles/P_DIQ.xpt
# Successfully downloaded https://wwwn.cdc.gov/Nchs/Data/Nhanes/Public/2017/DataFiles/P_DBQ.xpt
# Successfully downloaded https://wwwn.cdc.gov/Nchs/Data/Nhanes/Public/2017/DataFiles/P_ECQ.xpt
# Successfully downloaded https://wwwn.cdc.gov/Nchs/Data/Nhanes/Public/2017/DataFiles/P_FSQ.xpt
# Successfully downloaded https://wwwn.cdc.gov/Nchs/Data/Nhanes/Public/2017/DataFiles/P_HIQ.xpt
# Successfully downloaded https://wwwn.cdc.gov/Nchs/Data/Nhanes/Public/2017/DataFiles/P_HEQ.xpt
# Successfully downloaded https://wwwn.cdc.gov/Nchs/Data/Nhanes/Public/2017/DataFiles/P_HUQ.xpt
# Successfully downloaded https://wwwn.cdc.gov/Nchs/Data/Nhanes/Public/2017/DataFiles/P_IMQ.xpt
# Successfully downloaded https://wwwn.cdc.gov/Nchs/Data/Nhanes/Public/2017/DataFiles/P_INQ.xpt
# Successfully downloaded https://wwwn.cdc.gov/Nchs/Data/Nhanes/Public/2017/DataFiles/P_KIQ_U.xpt
# Successfully downloaded https://wwwn.cdc.gov/Nchs/Data/Nhanes/Public/2017/DataFiles/P_MCQ.xpt
# Successfully downloaded https://wwwn.cdc.gov/Nchs/Data/Nhanes/Public/2017/DataFiles/P_DPQ.xpt
# Successfully downloaded https://wwwn.cdc.gov/Nchs/Data/Nhanes/Public/2017/DataFiles/P_OCQ.xpt
# Successfully downloaded https://wwwn.cdc.gov/Nchs/Data/Nhanes/Public/2017/DataFiles/P_OHQ.xpt
# Successfully downloaded https://wwwn.cdc.gov/Nchs/Data/Nhanes/Public/2017/DataFiles/P_OSQ.xpt
# Successfully downloaded https://wwwn.cdc.gov/Nchs/Data/Nhanes/Public/2017/DataFiles/P_PUQMEC.xpt
# Successfully downloaded https://wwwn.cdc.gov/Nchs/Data/Nhanes/Public/2017/DataFiles/P_PAQ.xpt
# Successfully downloaded https://wwwn.cdc.gov/Nchs/Data/Nhanes/Public/2017/DataFiles/P_PAQY.xpt
# Successfully downloaded https://wwwn.cdc.gov/Nchs/Data/Nhanes/Public/2017/DataFiles/P_RXQ_RX.xpt
# Successfully downloaded https://wwwn.cdc.gov/Nchs/Data/Nhanes/Public/1988/DataFiles/RXQ_DRUG.xpt
# Successfully downloaded https://wwwn.cdc.gov/Nchs/Data/Nhanes/Public/2017/DataFiles/P_RXQASA.xpt
# Successfully downloaded https://wwwn.cdc.gov/Nchs/Data/Nhanes/Public/2017/DataFiles/P_RHQ.xpt
# Successfully downloaded https://wwwn.cdc.gov/Nchs/Data/Nhanes/Public/2017/DataFiles/P_SLQ.xpt
# Successfully downloaded https://wwwn.cdc.gov/Nchs/Data/Nhanes/Public/2017/DataFiles/P_SMQ.xpt
# Successfully downloaded https://wwwn.cdc.gov/Nchs/Data/Nhanes/Public/2017/DataFiles/P_SMQFAM.xpt
# Successfully downloaded https://wwwn.cdc.gov/Nchs/Data/Nhanes/Public/2017/DataFiles/P_SMQRTU.xpt
# Successfully downloaded https://wwwn.cdc.gov/Nchs/Data/Nhanes/Public/2017/DataFiles/P_SMQSHS.xpt
# Successfully downloaded https://wwwn.cdc.gov/Nchs/Data/Nhanes/Public/2017/DataFiles/P_VTQ.xpt
# Successfully downloaded https://wwwn.cdc.gov/Nchs/Data/Nhanes/Public/2017/DataFiles/P_WHQ.xpt
# Successfully downloaded https://wwwn.cdc.gov/Nchs/Data/Nhanes/Public/2017/DataFiles/P_WHQMEC.xpt
# Can't find codebook for https://wwwn.cdc.gov/Nchs/Data/Nhanes/Public/1988/DataFiles/RXQ_DRUG.htm!

# %%
import re
from io import StringIO


# INVALID_PATTERN = re.compile(
#     r"(refused|don['']?t\s*know|missing|blank but applicable|"
#     r"(can|could)\s*not\s*assess|unknown|not\s*ascertained)",
#     re.IGNORECASE
# )

# chg to non-capturing groups (?:...) instead of capturing groups (...)
INVALID_PATTERN = re.compile(
    r"(?:refused|don['']?t\s*know|missing|blank but applicable|"
    r"(?:can|could)\s*not\s*assess|unknown|not\s*ascertained)",
    re.IGNORECASE
)

# get invalid code
def get_invalid_codes(doc_url):
    result = {}
    soup = get_soup(doc_url)
    codebook = soup.find('div', id='Codebook')
    if not codebook:
        return result

    for block in codebook.select('div.pagebreak'):
        try:
            # variable name
            var_dt = block.find('dt', string=re.compile(r'Variable Name', re.I))
            var_name = var_dt.find_next_sibling('dd').get_text(strip=True)

            # Fix: Wrap HTML string in StringIO
            tables = pd.read_html(StringIO(str(block)))
            for df in tables:
                if "Code or Value" in df.columns and "Value Description" in df.columns:
                    # rows with invalid desc
                    # regex warning handled by using non-capturing groups above
                    invalid = df["Value Description"].astype(str).str.contains(INVALID_PATTERN, na=False)
                    if invalid.any():
                        codes = df.loc[invalid, "Code or Value"].astype(str).str.strip().tolist()
                        result[var_name] = codes
                    break
        except:
            pass

    return result

# invalid_codes from all pages
def build_invalid_map(category_df):
    invalid_map = {}
    for url in category_df["doc_url"].dropna():
        try:
            invalid_map.update(get_invalid_codes(url))
        except:
            pass
    return invalid_map

# run
subset_url = "https://wwwn.cdc.gov/nchs/nhanes/search/datapage.aspx?Component=Questionnaire&Cycle=2017-2020"
subset_df = get_category_subset_df(subset_url)
invalid_map = build_invalid_map(subset_df)

# %%
# Save the invalid map to a CSV file

df_invalid_map = pd.DataFrame([
    {'variable': var, 'invalid_code': code}
    for var, codes in invalid_map.items()
    for code in codes
])

directory = "./PROCESSED/DATA"
if not os.path.exists(directory):
    os.makedirs(directory)
save_path = directory + "/invalid_map_questionnaire_2017_2020.csv"
df_invalid_map.to_csv(save_path, index = False)
print(f"Saved invalid_map_questionnaire_2017_2020.csv to {save_path}")
# Out:
# Saved invalid_map_questionnaire_2017_2020.csv to ./PROCESSED/DATA/invalid_map_questionnaire_2017_2020.csv
